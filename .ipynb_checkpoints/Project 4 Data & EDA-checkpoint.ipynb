# %%
import requests
import json
import pandas as pd

# %% [markdown]
# ## Obtain API Key to Access Data

# %%
api_key = 'ZXCH94jmLisJ8b72hhJC31sCKyZHmEwBxTcp763u'

# %% [markdown]
# ## Obtain Data

# %%
# https://api.data.gov/ed/collegescorecard/v1/schools?

#     &fields=school.name,school.ownership,school.state_fips,school.region_id,
#     school.tuition_revenue_per_fte,school.instructional_expenditure_per_fte,
#     school.faculty_salary,school.ft_faculty_rate,
#     2015.admissions.admission_rate.overall,
#     2015.aid.pell_grant_rate,2015.aid.federal_loan_rate,
#     2015.aid.median_debt.completers.overall,
#     2015.student.size,
#     2015.cost.attendance.academic_year&school.main_campus=1&school.degrees_awarded.predominant=3
# &school.operating=1&school.online_only=0&school.institutional_characteristics.level=1]

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=

# school.name,id,
# 2015.cost.avg_net_price.overall,
# 2015.cost.net_price.public.by_income_level.0-30000,
# 2015.cost.net_price.public.by_income_level.110001-plus,
# 2015.cost.net_price.public.by_income_level.30001-48000,
# 2015.cost.net_price.public.by_income_level.48001-75000,
# 2015.cost.net_price.public.by_income_level.75001-110000,
# 2015.cost.net_price.public.by_income_level.75000-plus,
# 2015.cost.net_price.private.by_income_level.0-30000,
# 2015.cost.net_price.private.by_income_level.110001-plus,
# 2015.cost.net_price.private.by_income_level.30001-48000,
# 2015.cost.net_price.private.by_income_level.48001-75000,
# 2015.cost.net_price.private.by_income_level.75001-110000,
# 2015.cost.net_price.private.by_income_level.75000-plus,
# 2015.admissions.sat_scores.25th_percentile.critical_reading,
# 2015.admissions.sat_scores.25th_percentile.math,
# 2015.admissions.sat_scores.25th_percentile.writing,
# 2015.admissions.sat_scores.75th_percentile.critical_reading,
# 2015.admissions.sat_scores.75th_percentile.math,
# 2015.admissions.sat_scores.75th_percentile.writing'
# 2015.admissions.act_scores.25th_percentile.cumulative,
# 2015.admissions.act_scores.75th_percentile.cumulative,
# 2015.admissions.admission_rate.overall,
# 2015.student.size,
# 2015.cost.attendance.academic_year,
# school.tuition_revenue_per_fte,
# school.instructional_expenditure_per_fte,
# school.degrees_awarded.predominant,
# 2015.aid.pell_grant_rate,
# 2015.aid.federal_loan_rate,
# 2015.aid.median_debt.completers.overall,
# 2015.repayment.1_yr_repayment.completers,
# 2015.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings

# &school.main_campus=1
# &school.operating=1&school.online_only=0&school.institutional_characteristics.level=1'

# %%
link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=school.name,id,2015.cost.avg_net_price.overall,2015.cost.net_price.public.by_income_level.0-30000,2015.cost.net_price.public.by_income_level.110001-plus,2015.cost.net_price.public.by_income_level.30001-48000,2015.cost.net_price.public.by_income_level.48001-75000,2015.cost.net_price.public.by_income_level.75001-110000,2015.cost.net_price.public.by_income_level.75000-plus,2015.cost.net_price.private.by_income_level.0-30000,2015.cost.net_price.private.by_income_level.110001-plus,2015.cost.net_price.private.by_income_level.30001-48000,2015.cost.net_price.private.by_income_level.48001-75000,2015.cost.net_price.private.by_income_level.75001-110000,2015.cost.net_price.private.by_income_level.75000-plus,2015.admissions.sat_scores.average.overall,2015.admissions.sat_scores.25th_percentile.critical_reading,2015.admissions.sat_scores.25th_percentile.math,2015.admissions.sat_scores.25th_percentile.writing,2015.admissions.sat_scores.75th_percentile.critical_reading,2015.admissions.sat_scores.75th_percentile.math,2015.admissions.sat_scores.75th_percentile.writing,2015.admissions.act_scores.25th_percentile.cumulative,2015.admissions.act_scores.75th_percentile.cumulative,2015.admissions.admission_rate.overall,2015.student.size,2015.cost.attendance.academic_year,school.tuition_revenue_per_fte,school.instructional_expenditure_per_fte,school.degrees_awarded.predominant,2015.aid.pell_grant_rate,2015.aid.federal_loan_rate,2015.aid.median_debt.completers.overall,2013.repayment.1_yr_repayment.completers,2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings&school.main_campus=1&school.operating=1&school.online_only=0&school.institutional_characteristics.level=1&2015.academics.program_available.assoc_or_bachelors=True'

# %%
    'earnings': {'10_yrs_after_entry': {'female_students': None,
      'independent_students': None,
      'male_students': None,
      'mean_earnings': {'dependent_students': None,
       'dependent_students_lowest_tercile': None,
       'female_students': None,
       'highest_tercile': None,
       'independent_students': None,
       'lowest_tercile': None,
       'male_students': None,
       'middle_tercile': None},
      'median': None,
      'not_working_not_enrolled': {'overall': None},
      'percent_greater_than_25000': None,
      'working_not_enrolled': {'dependent_students': None,
       'dependent_students_lowest_tercile': None,
       'earnings_percentile': {'10': None, '25': None, '75': None, '90': None},
       'income': {'highest_tercile': None,
        'lowest_tercile': None,
        'middle_tercile': None},
       'mean_earnings': None,
       'overall': None,
       'std_dev': None}},

# %%
params = {
        'api_key':api_key,
        '_page':1,
        '_per_page':100}

# %%
res = requests.get(link, params)
schools = json.loads(res.content)

# %%
schools
# Out:
# {'metadata': {'page': 1, 'per_page': 100, 'total': 2109},
#  'results': [{'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 81400,
#    '2013.repayment.1_yr_repayment.completers': 682,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 22.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 29.0,
#    '2015.admissions.admission_rate.overall': 0.6456,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 490.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 520.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 490.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 620.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 660.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 630.0,
#    '2015.admissions.sat_scores.average.overall': 1152.0,
#    '2015.aid.federal_loan_rate': 0.5601,
#    '2015.aid.median_debt.completers.overall': 24625.0,
#    '2015.aid.pell_grant_rate': 0.3738,
#    '2015.cost.attendance.academic_year': 55473,
#    '2015.cost.avg_net_price.overall': 30108,
#    '2015.cost.net_price.private.by_income_level.0-30000': 22826,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 37989,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 26172,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 28074,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 36287,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 33095,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 3720,
#    'id': 120883,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 19706,
#    'school.name': 'University of the Pacific',
#    'school.tuition_revenue_per_fte': 31196},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 34900,
#    '2013.repayment.1_yr_repayment.completers': 83,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.8593,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.378,
#    '2015.aid.median_debt.completers.overall': None,
#    '2015.aid.pell_grant_rate': 0.2639,
#    '2015.cost.attendance.academic_year': 39655,
#    '2015.cost.avg_net_price.overall': 36757,
#    '2015.cost.net_price.private.by_income_level.0-30000': 35255,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 39270,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 36335,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 38047,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 39286,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 39316,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 1040,
#    'id': 119270,
#    'school.degrees_awarded.predominant': 1,
#    'school.instructional_expenditure_per_fte': 10973,
#    'school.name': 'Musicians Institute',
#    'school.tuition_revenue_per_fte': 23479},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': None,
#    '2013.repayment.1_yr_repayment.completers': 25,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.732,
#    '2015.aid.median_debt.completers.overall': 18000.0,
#    '2015.aid.pell_grant_rate': 0.5876,
#    '2015.cost.attendance.academic_year': None,
#    '2015.cost.avg_net_price.overall': None,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 168,
#    'id': 120698,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 16568,
#    'school.name': 'Palo Alto University',
#    'school.tuition_revenue_per_fte': 24561},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 42800,
#    '2013.repayment.1_yr_repayment.completers': 53,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.419,
#    '2015.aid.median_debt.completers.overall': 26937.5,
#    '2015.aid.pell_grant_rate': 0.2143,
#    '2015.cost.attendance.academic_year': None,
#    '2015.cost.avg_net_price.overall': None,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 196,
#    'id': 116226,
#    'school.degrees_awarded.predominant': 2,
#    'school.instructional_expenditure_per_fte': 3625,
#    'school.name': 'Interior Designers Institute',
#    'school.tuition_revenue_per_fte': 22801},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': None,
#    '2013.repayment.1_yr_repayment.completers': None,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.0727,
#    '2015.aid.median_debt.completers.overall': None,
#    '2015.aid.pell_grant_rate': 0.0523,
#    '2015.cost.attendance.academic_year': 18923,
#    '2015.cost.avg_net_price.overall': 13400,
#    '2015.cost.net_price.private.by_income_level.0-30000': 10262,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 16538,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 70,
#    'id': 117672,
#    'school.degrees_awarded.predominant': 1,
#    'school.instructional_expenditure_per_fte': 11024,
#    'school.name': 'Southern California University of Health Sciences',
#    'school.tuition_revenue_per_fte': 21007},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 65700,
#    '2013.repayment.1_yr_repayment.completers': 1184,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 25.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 30.0,
#    '2015.admissions.admission_rate.overall': 0.5078,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 550.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 560.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 550.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 640.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 660.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 650.0,
#    '2015.admissions.sat_scores.average.overall': 1222.0,
#    '2015.aid.federal_loan_rate': 0.4516,
#    '2015.aid.median_debt.completers.overall': 21668.0,
#    '2015.aid.pell_grant_rate': 0.1957,
#    '2015.cost.attendance.academic_year': 58531,
#    '2015.cost.avg_net_price.overall': 37606,
#    '2015.cost.net_price.private.by_income_level.0-30000': 26562,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 46039,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 27553,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 29603,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 44015,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 37301,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 6162,
#    'id': 117946,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 16208,
#    'school.name': 'Loyola Marymount University',
#    'school.tuition_revenue_per_fte': 30462},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 43600,
#    '2013.repayment.1_yr_repayment.completers': 623,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 19.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 24.0,
#    '2015.admissions.admission_rate.overall': 0.6313,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 440.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 440.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 440.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 530.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 547.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 525.0,
#    '2015.admissions.sat_scores.average.overall': 988.0,
#    '2015.aid.federal_loan_rate': 0.6812,
#    '2015.aid.median_debt.completers.overall': 21500.0,
#    '2015.aid.pell_grant_rate': 0.5603,
#    '2015.cost.attendance.academic_year': 35787,
#    '2015.cost.avg_net_price.overall': 16117,
#    '2015.cost.net_price.private.by_income_level.0-30000': 13714,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 20881,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 12074,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 16088,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 20423,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 19946,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 2342,
#    'id': 114813,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 6169,
#    'school.name': 'Fresno Pacific University',
#    'school.tuition_revenue_per_fte': 13674},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 31100,
#    '2013.repayment.1_yr_repayment.completers': 173,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.6239,
#    '2015.aid.median_debt.completers.overall': 31368.0,
#    '2015.aid.pell_grant_rate': 0.6103,
#    '2015.cost.attendance.academic_year': 21436,
#    '2015.cost.avg_net_price.overall': 12617,
#    '2015.cost.net_price.private.by_income_level.0-30000': 11587,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 12438,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 17856,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 16894,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 16894,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 438,
#    'id': 115773,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 4279,
#    'school.name': 'Humphreys University-Stockton and Modesto Campuses',
#    'school.tuition_revenue_per_fte': 12162},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 68800,
#    '2013.repayment.1_yr_repayment.completers': 41,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.6074,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.4092,
#    '2015.aid.median_debt.completers.overall': 31163.0,
#    '2015.aid.pell_grant_rate': 0.4894,
#    '2015.cost.attendance.academic_year': 28780,
#    '2015.cost.avg_net_price.overall': 21506,
#    '2015.cost.net_price.private.by_income_level.0-30000': 18082,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 26938,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 19301,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 23461,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 25410,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 23595,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 630,
#    'id': 112394,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 7697,
#    'school.name': 'Cogswell College',
#    'school.tuition_revenue_per_fte': 15703},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 84900,
#    '2013.repayment.1_yr_repayment.completers': 144,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 32.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 35.0,
#    '2015.admissions.admission_rate.overall': 0.1296,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 670.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 730.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 680.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 760.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 800.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 760.0,
#    '2015.admissions.sat_scores.average.overall': 1484.0,
#    '2015.aid.federal_loan_rate': 0.398,
#    '2015.aid.median_debt.completers.overall': 25540.5,
#    '2015.aid.pell_grant_rate': 0.1269,
#    '2015.cost.attendance.academic_year': 66627,
#    '2015.cost.avg_net_price.overall': 29865,
#    '2015.cost.net_price.private.by_income_level.0-30000': 10165,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 45017,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 17925,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 22037,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 36615,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 21338,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 812,
#    'id': 115409,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 32257,
#    'school.name': 'Harvey Mudd College',
#    'school.tuition_revenue_per_fte': 28947},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 40100,
#    '2013.repayment.1_yr_repayment.completers': 80,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.3727,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.6409,
#    '2015.aid.median_debt.completers.overall': 26699.5,
#    '2015.aid.pell_grant_rate': 0.3959,
#    '2015.cost.attendance.academic_year': 43806,
#    '2015.cost.avg_net_price.overall': 32686,
#    '2015.cost.net_price.private.by_income_level.0-30000': 30345,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 34537,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 35321,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 25410,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 34640,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 34763,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 571,
#    'id': 117168,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 10390,
#    'school.name': 'Laguna College of Art and Design',
#    'school.tuition_revenue_per_fte': 18491},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 44200,
#    '2013.repayment.1_yr_repayment.completers': 2147,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.7685,
#    '2015.aid.median_debt.completers.overall': 14875.0,
#    '2015.aid.pell_grant_rate': 0.7867,
#    '2015.cost.attendance.academic_year': 30017,
#    '2015.cost.avg_net_price.overall': 25372,
#    '2015.cost.net_price.private.by_income_level.0-30000': 25233,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 27012,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 27457,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 25329,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 25329,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 1910,
#    'id': 102845,
#    'school.degrees_awarded.predominant': 1,
#    'school.instructional_expenditure_per_fte': 2076,
#    'school.name': 'Charter College',
#    'school.tuition_revenue_per_fte': 6971},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 32500,
#    '2013.repayment.1_yr_repayment.completers': 106,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.5706,
#    '2015.aid.median_debt.completers.overall': 50750.0,
#    '2015.aid.pell_grant_rate': 0.4068,
#    '2015.cost.attendance.academic_year': 38376,
#    '2015.cost.avg_net_price.overall': 36108,
#    '2015.cost.net_price.private.by_income_level.0-30000': 35574,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 37126,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 36786,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 37501,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 37876,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 131,
#    'id': 104188,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 4049,
#    'school.name': 'Southwest University of Visual Arts-Tucson',
#    'school.tuition_revenue_per_fte': 18060},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 42200,
#    '2013.repayment.1_yr_repayment.completers': 80,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 20.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 25.0,
#    '2015.admissions.admission_rate.overall': 0.9677,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 420.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 430.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 400.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 540.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 520.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 520.0,
#    '2015.admissions.sat_scores.average.overall': 1034.0,
#    '2015.aid.federal_loan_rate': 0.4736,
#    '2015.aid.median_debt.completers.overall': 22540.0,
#    '2015.aid.pell_grant_rate': 0.4327,
#    '2015.cost.attendance.academic_year': 35792,
#    '2015.cost.avg_net_price.overall': 14723,
#    '2015.cost.net_price.private.by_income_level.0-30000': 12704,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 21400,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 12719,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 14145,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 19427,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 18082,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 640,
#    'id': 107558,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 10250,
#    'school.name': 'University of the Ozarks',
#    'school.tuition_revenue_per_fte': 10999},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 45600,
#    '2013.repayment.1_yr_repayment.completers': 96,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 17.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 26.0,
#    '2015.admissions.admission_rate.overall': 0.3891,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 415.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 415.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 390.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 570.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 545.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 520.0,
#    '2015.admissions.sat_scores.average.overall': 985.0,
#    '2015.aid.federal_loan_rate': 0.4847,
#    '2015.aid.median_debt.completers.overall': 23250.0,
#    '2015.aid.pell_grant_rate': 0.2761,
#    '2015.cost.attendance.academic_year': 31435,
#    '2015.cost.avg_net_price.overall': 18218,
#    '2015.cost.net_price.private.by_income_level.0-30000': 21638,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 21040,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 15305,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 13749,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 20360,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 19850,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 254,
#    'id': 102669,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 12342,
#    'school.name': 'Alaska Pacific University',
#    'school.tuition_revenue_per_fte': 13109},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 33500,
#    '2013.repayment.1_yr_repayment.completers': 72,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 19.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 23.0,
#    '2015.admissions.admission_rate.overall': 0.5123,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 430.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 473.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 560.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 550.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': 997.0,
#    '2015.aid.federal_loan_rate': 0.4098,
#    '2015.aid.median_debt.completers.overall': 22500.0,
#    '2015.aid.pell_grant_rate': 0.2809,
#    '2015.cost.attendance.academic_year': 34794,
#    '2015.cost.avg_net_price.overall': 27570,
#    '2015.cost.net_price.private.by_income_level.0-30000': 26093,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 29436,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 25868,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 27705,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 28735,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 28033,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 644,
#    'id': 105899,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 5967,
#    'school.name': 'Arizona Christian University',
#    'school.tuition_revenue_per_fte': 9003},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 50400,
#    '2013.repayment.1_yr_repayment.completers': 253,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.2493,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.5649,
#    '2015.aid.median_debt.completers.overall': 28500.0,
#    '2015.aid.pell_grant_rate': 0.3082,
#    '2015.cost.attendance.academic_year': 62437,
#    '2015.cost.avg_net_price.overall': 46197,
#    '2015.cost.net_price.private.by_income_level.0-30000': 40649,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 50580,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 41519,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 46743,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 50004,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 48851,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 942,
#    'id': 111081,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 21405,
#    'school.name': 'California Institute of the Arts',
#    'school.tuition_revenue_per_fte': 28507},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 58300,
#    '2013.repayment.1_yr_repayment.completers': 448,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.7951,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.4677,
#    '2015.aid.median_debt.completers.overall': 31250.0,
#    '2015.aid.pell_grant_rate': 0.3043,
#    '2015.cost.attendance.academic_year': 59787,
#    '2015.cost.avg_net_price.overall': 44145,
#    '2015.cost.net_price.private.by_income_level.0-30000': 40080,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 51615,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 36560,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 42495,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 50494,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 48173,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 1890,
#    'id': 109651,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 19905,
#    'school.name': 'Art Center College of Design',
#    'school.tuition_revenue_per_fte': 29726},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 90500,
#    '2013.repayment.1_yr_repayment.completers': 174,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.6617,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.5769,
#    '2015.aid.median_debt.completers.overall': 25526.0,
#    '2015.aid.pell_grant_rate': 0.3238,
#    '2015.cost.attendance.academic_year': 22023,
#    '2015.cost.avg_net_price.overall': 15206,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 8321,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 21221,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 9700,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 13854,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 20477,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 18671,
#    '2015.student.size': 1072,
#    'id': 111188,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 18783,
#    'school.name': 'California State University Maritime Academy',
#    'school.tuition_revenue_per_fte': 9465},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 97800,
#    '2013.repayment.1_yr_repayment.completers': 67,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 29.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 33.0,
#    '2015.admissions.admission_rate.overall': 0.1096,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 670.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 670.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 690.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 750.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 780.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 760.0,
#    '2015.admissions.sat_scores.average.overall': 1408.0,
#    '2015.aid.federal_loan_rate': 0.1514,
#    '2015.aid.median_debt.completers.overall': 14967.5,
#    '2015.aid.pell_grant_rate': 0.1153,
#    '2015.cost.attendance.academic_year': 64215,
#    '2015.cost.avg_net_price.overall': 24298,
#    '2015.cost.net_price.private.by_income_level.0-30000': 8634,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 36704,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 7701,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 16705,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 34225,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 27850,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 1325,
#    'id': 112260,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 27189,
#    'school.name': 'Claremont McKenna College',
#    'school.tuition_revenue_per_fte': 31936},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': None,
#    '2013.repayment.1_yr_repayment.completers': None,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': 0.5842,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.0,
#    '2015.aid.median_debt.completers.overall': None,
#    '2015.aid.pell_grant_rate': 0.6687,
#    '2015.cost.attendance.academic_year': 24850,
#    '2015.cost.avg_net_price.overall': 7517,
#    '2015.cost.net_price.private.by_income_level.0-30000': 7027,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 5550,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 8667,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 13700,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 13700,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 161,
#    'id': 126076,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 10505,
#    'school.name': 'Yeshiva Ohr Elchonon Chabad West Coast Talmudical Seminary',
#    'school.tuition_revenue_per_fte': 12391},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 56900,
#    '2013.repayment.1_yr_repayment.completers': 3793,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 24.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 30.0,
#    '2015.admissions.admission_rate.overall': 0.7962,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 530.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 540.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 640.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 660.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': 1212.0,
#    '2015.aid.federal_loan_rate': 0.3068,
#    '2015.aid.median_debt.completers.overall': 19500.0,
#    '2015.aid.pell_grant_rate': 0.1723,
#    '2015.cost.attendance.academic_year': 30025,
#    '2015.cost.avg_net_price.overall': 21806,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 13714,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 28201,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 16033,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 20982,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 27527,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 26184,
#    '2015.student.size': 26496,
#    'id': 126614,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 15174,
#    'school.name': 'University of Colorado Boulder',
#    'school.tuition_revenue_per_fte': 18327},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 58600,
#    '2013.repayment.1_yr_repayment.completers': 9542,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.632,
#    '2015.aid.median_debt.completers.overall': 33706.0,
#    '2015.aid.pell_grant_rate': 0.507,
#    '2015.cost.attendance.academic_year': 24692,
#    '2015.cost.avg_net_price.overall': 20732,
#    '2015.cost.net_price.private.by_income_level.0-30000': 19889,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 24692,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 18974,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 22405,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 24692,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 24692,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 1135,
#    'id': 126827,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 3758,
#    'school.name': 'Colorado Technical University-Colorado Springs',
#    'school.tuition_revenue_per_fte': 14655},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 46400,
#    '2013.repayment.1_yr_repayment.completers': 36,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 24.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 29.0,
#    '2015.admissions.admission_rate.overall': 0.7336,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 435.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 535.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 465.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 565.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 685.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 570.0,
#    '2015.admissions.sat_scores.average.overall': 1116.0,
#    '2015.aid.federal_loan_rate': 0.2814,
#    '2015.aid.median_debt.completers.overall': 42750.0,
#    '2015.aid.pell_grant_rate': 0.3118,
#    '2015.cost.attendance.academic_year': 65657,
#    '2015.cost.avg_net_price.overall': 52073,
# ...
#    '2015.admissions.sat_scores.25th_percentile.math': 700.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 590.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 680.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 790.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 690.0,
#    '2015.admissions.sat_scores.average.overall': 1305.0,
#    '2015.aid.federal_loan_rate': 0.3759,
#    '2015.aid.median_debt.completers.overall': 20500.0,
#    '2015.aid.pell_grant_rate': 0.2049,
#    '2015.cost.attendance.academic_year': 29568,
#    '2015.cost.avg_net_price.overall': 18143,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 6906,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 27207,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 11154,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 16974,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 26183,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 23933,
#    '2015.student.size': 32170,
#    'id': 145637,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 14212,
#    'school.name': 'University of Illinois at Urbana-Champaign',
#    'school.tuition_revenue_per_fte': 14395},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 38300,
#    '2013.repayment.1_yr_repayment.completers': 1059,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 16.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 20.0,
#    '2015.admissions.admission_rate.overall': 0.2118,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 435.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 493.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 518.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 560.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': 875.0,
#    '2015.aid.federal_loan_rate': 0.9228,
#    '2015.aid.median_debt.completers.overall': 31250.0,
#    '2015.aid.pell_grant_rate': 0.7078,
#    '2015.cost.attendance.academic_year': 20305,
#    '2015.cost.avg_net_price.overall': 11689,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 11254,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 12346,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 13720,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 14592,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 14592,
#    '2015.student.size': 3437,
#    'id': 144005,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 15813,
#    'school.name': 'Chicago State University',
#    'school.tuition_revenue_per_fte': 6853},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 46900,
#    '2013.repayment.1_yr_repayment.completers': 1700,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 20.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 26.0,
#    '2015.admissions.admission_rate.overall': 0.7205,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 470.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 470.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 440.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 590.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 580.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 560.0,
#    '2015.admissions.sat_scores.average.overall': 1061.0,
#    '2015.aid.federal_loan_rate': 0.5263,
#    '2015.aid.median_debt.completers.overall': 24279.0,
#    '2015.aid.pell_grant_rate': 0.3925,
#    '2015.cost.attendance.academic_year': 19418,
#    '2015.cost.avg_net_price.overall': 13709,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 10891,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 17838,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 12077,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 14474,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 17286,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 16875,
#    '2015.student.size': 7826,
#    'id': 142285,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 11339,
#    'school.name': 'University of Idaho',
#    'school.tuition_revenue_per_fte': 8766},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 41000,
#    '2013.repayment.1_yr_repayment.completers': 235,
#    '2015.admissions.act_scores.25th_percentile.cumulative': None,
#    '2015.admissions.act_scores.75th_percentile.cumulative': None,
#    '2015.admissions.admission_rate.overall': None,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': None,
#    '2015.aid.federal_loan_rate': 0.7819,
#    '2015.aid.median_debt.completers.overall': 39290.5,
#    '2015.aid.pell_grant_rate': 0.4799,
#    '2015.cost.attendance.academic_year': None,
#    '2015.cost.avg_net_price.overall': None,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 25,
#    'id': 145460,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 9896,
#    'school.name': 'Harrington College of Design',
#    'school.tuition_revenue_per_fte': 21446},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 47600,
#    '2013.repayment.1_yr_repayment.completers': 4660,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 19.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 25.0,
#    '2015.admissions.admission_rate.overall': 0.5035,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 450.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 450.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 410.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 530.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 550.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 520.0,
#    '2015.admissions.sat_scores.average.overall': 1029.0,
#    '2015.aid.federal_loan_rate': 0.6674,
#    '2015.aid.median_debt.completers.overall': 23859.0,
#    '2015.aid.pell_grant_rate': 0.4452,
#    '2015.cost.attendance.academic_year': 27837,
#    '2015.cost.avg_net_price.overall': 19259,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 17030,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 23792,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 17215,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 19448,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 22823,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 21565,
#    '2015.student.size': 14952,
#    'id': 147703,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 13294,
#    'school.name': 'Northern Illinois University',
#    'school.tuition_revenue_per_fte': 7669},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': None,
#    '2013.repayment.1_yr_repayment.completers': 40,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 22.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 28.0,
#    '2015.admissions.admission_rate.overall': 0.9574,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 368.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 478.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 480.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 472.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 612.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 510.0,
#    '2015.admissions.sat_scores.average.overall': 1107.0,
#    '2015.aid.federal_loan_rate': 0.6081,
#    '2015.aid.median_debt.completers.overall': 27000.0,
#    '2015.aid.pell_grant_rate': 0.3378,
#    '2015.cost.attendance.academic_year': 38764,
#    '2015.cost.avg_net_price.overall': 25287,
#    '2015.cost.net_price.private.by_income_level.0-30000': 26573,
#    '2015.cost.net_price.private.by_income_level.110001-plus': 26611,
#    '2015.cost.net_price.private.by_income_level.30001-48000': 25474,
#    '2015.cost.net_price.private.by_income_level.48001-75000': 22806,
#    '2015.cost.net_price.private.by_income_level.75000-plus': 26030,
#    '2015.cost.net_price.private.by_income_level.75001-110000': 25545,
#    '2015.cost.net_price.public.by_income_level.0-30000': None,
#    '2015.cost.net_price.public.by_income_level.110001-plus': None,
#    '2015.cost.net_price.public.by_income_level.30001-48000': None,
#    '2015.cost.net_price.public.by_income_level.48001-75000': None,
#    '2015.cost.net_price.public.by_income_level.75000-plus': None,
#    '2015.cost.net_price.public.by_income_level.75001-110000': None,
#    '2015.student.size': 104,
#    'id': 149639,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 6676,
#    'school.name': 'VanderCook College of Music',
#    'school.tuition_revenue_per_fte': 14189},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 46000,
#    '2013.repayment.1_yr_repayment.completers': 2832,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 18.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 23.0,
#    '2015.admissions.admission_rate.overall': 0.6007,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.25th_percentile.math': None,
#    '2015.admissions.sat_scores.25th_percentile.writing': None,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2015.admissions.sat_scores.75th_percentile.math': None,
#    '2015.admissions.sat_scores.75th_percentile.writing': None,
#    '2015.admissions.sat_scores.average.overall': 970.0,
#    '2015.aid.federal_loan_rate': 0.7047,
#    '2015.aid.median_debt.completers.overall': 24704.0,
#    '2015.aid.pell_grant_rate': 0.4621,
#    '2015.cost.attendance.academic_year': 25234,
#    '2015.cost.avg_net_price.overall': 17219,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 13864,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 22557,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 15159,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 18834,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 22176,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 21779,
#    '2015.student.size': 9141,
#    'id': 149772,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 12174,
#    'school.name': 'Western Illinois University',
#    'school.tuition_revenue_per_fte': 7393},
#   {'2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings': 39500,
#    '2013.repayment.1_yr_repayment.completers': 269,
#    '2015.admissions.act_scores.25th_percentile.cumulative': 17.0,
#    '2015.admissions.act_scores.75th_percentile.cumulative': 23.0,
#    '2015.admissions.admission_rate.overall': 0.7928,
#    '2015.admissions.sat_scores.25th_percentile.critical_reading': 400.0,
#    '2015.admissions.sat_scores.25th_percentile.math': 400.0,
#    '2015.admissions.sat_scores.25th_percentile.writing': 400.0,
#    '2015.admissions.sat_scores.75th_percentile.critical_reading': 510.0,
#    '2015.admissions.sat_scores.75th_percentile.math': 510.0,
#    '2015.admissions.sat_scores.75th_percentile.writing': 500.0,
#    '2015.admissions.sat_scores.average.overall': 928.0,
#    '2015.aid.federal_loan_rate': 0.3605,
#    '2015.aid.median_debt.completers.overall': 25030.0,
#    '2015.aid.pell_grant_rate': 0.3038,
#    '2015.cost.attendance.academic_year': 14108,
#    '2015.cost.avg_net_price.overall': 8549,
#    '2015.cost.net_price.private.by_income_level.0-30000': None,
#    '2015.cost.net_price.private.by_income_level.110001-plus': None,
#    '2015.cost.net_price.private.by_income_level.30001-48000': None,
#    '2015.cost.net_price.private.by_income_level.48001-75000': None,
#    '2015.cost.net_price.private.by_income_level.75000-plus': None,
#    '2015.cost.net_price.private.by_income_level.75001-110000': None,
#    '2015.cost.net_price.public.by_income_level.0-30000': 4812,
#    '2015.cost.net_price.public.by_income_level.110001-plus': 13631,
#    '2015.cost.net_price.public.by_income_level.30001-48000': 5411,
#    '2015.cost.net_price.public.by_income_level.48001-75000': 11010,
#    '2015.cost.net_price.public.by_income_level.75000-plus': 13458,
#    '2015.cost.net_price.public.by_income_level.75001-110000': 13326,
#    '2015.student.size': 4117,
#    'id': 151360,
#    'school.degrees_awarded.predominant': 3,
#    'school.instructional_expenditure_per_fte': 6441,
#    'school.name': 'Indiana University-Northwest',
#    'school.tuition_revenue_per_fte': 5323}]}

# %%
school_df = pd.DataFrame(schools['results'])

# %% [markdown]
# ### Code below gives error message only when it's done collecting data on all schools matching criteria.

# %%
for x in range (2, 202):
    params = {
        'api_key':api_key,
        '_page':x,
        '_per_page':100}
    res = requests.get(link, params)
    sc = json.loads(res.content)
    sc2 = pd.DataFrame(sc['results'])
    school_df = school_df.append(sc2)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-71-2efc247ee676> in <module>()
#       5         '_per_page':100}
#       6     res = requests.get(link, params)
# ----> 7     sc = json.loads(res.content)
#       8     sc2 = pd.DataFrame(sc['results'])
#       9     school_df = school_df.append(sc2)
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
school_df.shape
# Out:
# (2009, 35)

# %%
school_df.isnull().sum()
# Out:
# 2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings     174
# 2013.repayment.1_yr_repayment.completers                                165
# 2015.admissions.act_scores.25th_percentile.cumulative                   863
# 2015.admissions.act_scores.75th_percentile.cumulative                   863
# 2015.admissions.admission_rate.overall                                  428
# 2015.admissions.sat_scores.25th_percentile.critical_reading             906
# 2015.admissions.sat_scores.25th_percentile.math                         897
# 2015.admissions.sat_scores.25th_percentile.writing                     1337
# 2015.admissions.sat_scores.75th_percentile.critical_reading             906
# 2015.admissions.sat_scores.75th_percentile.math                         897
# 2015.admissions.sat_scores.75th_percentile.writing                     1337
# 2015.admissions.sat_scores.average.overall                              827
# 2015.aid.federal_loan_rate                                                5
# 2015.aid.median_debt.completers.overall                                 162
# 2015.aid.pell_grant_rate                                                  5
# 2015.cost.attendance.academic_year                                      121
# 2015.cost.avg_net_price.overall                                         106
# 2015.cost.net_price.private.by_income_level.0-30000                     717
# 2015.cost.net_price.private.by_income_level.110001-plus                 921
# 2015.cost.net_price.private.by_income_level.30001-48000                 761
# 2015.cost.net_price.private.by_income_level.48001-75000                 779
# 2015.cost.net_price.private.by_income_level.75000-plus                  846
# 2015.cost.net_price.private.by_income_level.75001-110000                863
# 2015.cost.net_price.public.by_income_level.0-30000                     1412
# 2015.cost.net_price.public.by_income_level.110001-plus                 1449
# 2015.cost.net_price.public.by_income_level.30001-48000                 1415
# 2015.cost.net_price.public.by_income_level.48001-75000                 1418
# 2015.cost.net_price.public.by_income_level.75000-plus                  1428
# 2015.cost.net_price.public.by_income_level.75001-110000                1430
# 2015.student.size                                                         3
# id                                                                        0
# school.degrees_awarded.predominant                                        0
# school.instructional_expenditure_per_fte                                  0
# school.name                                                               0
# school.tuition_revenue_per_fte                                            0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# #### Feature Engineer: Filter Minimum Net Price, Maximum Net Price and Average Net Price

# %%
school_df['High_Net_Price'] = school_df[['2015.cost.avg_net_price.overall',
       '2015.cost.net_price.private.by_income_level.0-30000',
       '2015.cost.net_price.private.by_income_level.110001-plus',
       '2015.cost.net_price.private.by_income_level.30001-48000',
       '2015.cost.net_price.private.by_income_level.48001-75000',
       '2015.cost.net_price.private.by_income_level.75000-plus',
       '2015.cost.net_price.private.by_income_level.75001-110000',
       '2015.cost.net_price.public.by_income_level.0-30000',
       '2015.cost.net_price.public.by_income_level.110001-plus',
       '2015.cost.net_price.public.by_income_level.30001-48000',
       '2015.cost.net_price.public.by_income_level.48001-75000',
       '2015.cost.net_price.public.by_income_level.75000-plus',
       '2015.cost.net_price.public.by_income_level.75001-110000']].max(axis=1)

# %%
school_df['Low_Net_Price'] = school_df[['2015.cost.avg_net_price.overall',
       '2015.cost.net_price.private.by_income_level.0-30000',
       '2015.cost.net_price.private.by_income_level.110001-plus',
       '2015.cost.net_price.private.by_income_level.30001-48000',
       '2015.cost.net_price.private.by_income_level.48001-75000',
       '2015.cost.net_price.private.by_income_level.75000-plus',
       '2015.cost.net_price.private.by_income_level.75001-110000',
       '2015.cost.net_price.public.by_income_level.0-30000',
       '2015.cost.net_price.public.by_income_level.110001-plus',
       '2015.cost.net_price.public.by_income_level.30001-48000',
       '2015.cost.net_price.public.by_income_level.48001-75000',
       '2015.cost.net_price.public.by_income_level.75000-plus',
       '2015.cost.net_price.public.by_income_level.75001-110000']].min(axis=1)

# %%
school_df['Avg_Net_Price'] = school_df['2015.cost.avg_net_price.overall']

# %%
school_df['Total_Cost'] =

# %% [markdown]
# #### Feature Engineering:  Combine SAT Scores to Total (Eliminate Writing Score as many schools do not report)

# %%
school_df['SAT_25th_Cum'] = school_df['2015.admissions.sat_scores.25th_percentile.critical_reading'] + school_df['2015.admissions.sat_scores.25th_percentile.math']

# %%
school_df['SAT_75th_Cum'] = school_df['2015.admissions.sat_scores.75th_percentile.critical_reading'] + school_df['2015.admissions.sat_scores.75th_percentile.math']

# %% [markdown]
# #### Feature Engineering:   ACT Scores

# %%
school_df['ACT_25th'] = school_df['2015.admissions.act_scores.25th_percentile.cumulative']

# %%
school_df['ACT_75th'] = school_df['2015.admissions.act_scores.75th_percentile.cumulative']

# %% [markdown]
# #### Filter out columns that have been combined in feature engineering

# %%
school_2 = school_df[['2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings',
       '2015.admissions.admission_rate.overall',
       '2015.aid.federal_loan_rate', '2015.aid.median_debt.completers.overall',
       '2015.aid.pell_grant_rate',
       '2015.student.size', 'id', 'school.degrees_awarded.predominant', 'school.name', 'High_Net_Price', 'Low_Net_Price',
       'Avg_Net_Price', 'SAT_25th_Cum', 'SAT_75th_Cum', 'ACT_25th',
       'ACT_75th']]

# %%
school_2.isnull().sum()
# Out:
# 2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings    174
# 2015.admissions.admission_rate.overall                                 428
# 2015.aid.federal_loan_rate                                               5
# 2015.aid.median_debt.completers.overall                                162
# 2015.aid.pell_grant_rate                                                 5
# 2015.cost.attendance.academic_year                                     121
# 2015.student.size                                                        3
# id                                                                       0
# school.degrees_awarded.predominant                                       0
# school.instructional_expenditure_per_fte                                 0
# school.name                                                              0
# school.tuition_revenue_per_fte                                           0
# High_Net_Price                                                         106
# Low_Net_Price                                                          106
# Avg_Net_Price                                                          106
# SAT_25th_Cum                                                           906
# SAT_75th_Cum                                                           906
# ACT_25th                                                               863
# ACT_75th                                                               863
# dtype: int64

# %%
school_2.columns = ['Earnings_10yrs',
       'Admission_Rate', 'Fed_Loan_Rate',
       'Median_Debt', 'Pell_Grant_Rate','Student_Size', 'ID',
       'Degrees_Awarded', 'School_Name','High_Net_Price', 'Low_Net_Price',
       'Avg_Net_Price', 'SAT_25th_Cum', 'SAT_75th_Cum', 'ACT_25th',
       'ACT_75th']

# %%
x = 19706 + 31196
x
# Out:
# 50902

# %%
school_df.columns
# Out:
# Index(['2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings',
#        '2013.repayment.1_yr_repayment.completers',
#        '2015.admissions.act_scores.25th_percentile.cumulative',
#        '2015.admissions.act_scores.75th_percentile.cumulative',
#        '2015.admissions.admission_rate.overall',
#        '2015.admissions.sat_scores.25th_percentile.critical_reading',
#        '2015.admissions.sat_scores.25th_percentile.math',
#        '2015.admissions.sat_scores.25th_percentile.writing',
#        '2015.admissions.sat_scores.75th_percentile.critical_reading',
#        '2015.admissions.sat_scores.75th_percentile.math',
#        '2015.admissions.sat_scores.75th_percentile.writing',
#        '2015.admissions.sat_scores.average.overall',
#        '2015.aid.federal_loan_rate', '2015.aid.median_debt.completers.overall',
#        '2015.aid.pell_grant_rate', '2015.cost.attendance.academic_year',
#        '2015.cost.avg_net_price.overall',
#        '2015.cost.net_price.private.by_income_level.0-30000',
#        '2015.cost.net_price.private.by_income_level.110001-plus',
#        '2015.cost.net_price.private.by_income_level.30001-48000',
#        '2015.cost.net_price.private.by_income_level.48001-75000',
#        '2015.cost.net_price.private.by_income_level.75000-plus',
#        '2015.cost.net_price.private.by_income_level.75001-110000',
#        '2015.cost.net_price.public.by_income_level.0-30000',
#        '2015.cost.net_price.public.by_income_level.110001-plus',
#        '2015.cost.net_price.public.by_income_level.30001-48000',
#        '2015.cost.net_price.public.by_income_level.48001-75000',
#        '2015.cost.net_price.public.by_income_level.75000-plus',
#        '2015.cost.net_price.public.by_income_level.75001-110000',
#        '2015.student.size', 'id', 'school.degrees_awarded.predominant',
#        'school.instructional_expenditure_per_fte', 'school.name',
#        'school.tuition_revenue_per_fte', 'High_Net_Price', 'Low_Net_Price',
#        'Avg_Net_Price', 'SAT_25th_Cum', 'SAT_75th_Cum'],
#       dtype='object')

# %%
school_df.columns = ['2015.admissions.act_scores.25th_percentile.cumulative',
       '2015.admissions.act_scores.75th_percentile.cumulative',
       '2015.admissions.admission_rate.overall',
       '2015.admissions.sat_scores.25th_percentile.critical_reading',
       '2015.admissions.sat_scores.25th_percentile.math',
       '2015.admissions.sat_scores.25th_percentile.writing',
       '2015.admissions.sat_scores.75th_percentile.critical_reading',
       '2015.admissions.sat_scores.75th_percentile.math',
       '2015.admissions.sat_scores.75th_percentile.writing',
       '2015.admissions.sat_scores.average.overall',
       '2015.aid.federal_loan_rate', '2015.aid.median_debt.completers.overall',
       '2015.aid.pell_grant_rate', '2015.cost.attendance.academic_year',
       '2015.cost.avg_net_price.overall',
       '2015.cost.net_price.private.by_income_level.0-30000',
       '2015.cost.net_price.private.by_income_level.110001-plus',
       '2015.cost.net_price.private.by_income_level.30001-48000',
       '2015.cost.net_price.private.by_income_level.48001-75000',
       '2015.cost.net_price.private.by_income_level.75000-plus',
       '2015.cost.net_price.private.by_income_level.75001-110000',
       '2015.cost.net_price.public.by_income_level.0-30000',
       '2015.cost.net_price.public.by_income_level.110001-plus',
       '2015.cost.net_price.public.by_income_level.30001-48000',
       '2015.cost.net_price.public.by_income_level.48001-75000',
       '2015.cost.net_price.public.by_income_level.75000-plus',
       '2015.cost.net_price.public.by_income_level.75001-110000',
       '2015.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings',
       '2015.repayment.1_yr_repayment.completers', '2015.student.size', 'id',
       'school.degrees_awarded.predominant',
       'school.instructional_expenditure_per_fte', 'school.name',
       'school.tuition_revenue_per_fte']
# Out:
# Index(['2015.admissions.act_scores.25th_percentile.cumulative',
#        '2015.admissions.act_scores.75th_percentile.cumulative',
#        '2015.admissions.admission_rate.overall',
#        '2015.admissions.sat_scores.25th_percentile.critical_reading',
#        '2015.admissions.sat_scores.25th_percentile.math',
#        '2015.admissions.sat_scores.25th_percentile.writing',
#        '2015.admissions.sat_scores.75th_percentile.critical_reading',
#        '2015.admissions.sat_scores.75th_percentile.math',
#        '2015.admissions.sat_scores.75th_percentile.writing',
#        '2015.admissions.sat_scores.average.overall',
#        '2015.aid.federal_loan_rate', '2015.aid.median_debt.completers.overall',
#        '2015.aid.pell_grant_rate', '2015.cost.attendance.academic_year',
#        '2015.cost.avg_net_price.overall',
#        '2015.cost.net_price.private.by_income_level.0-30000',
#        '2015.cost.net_price.private.by_income_level.110001-plus',
#        '2015.cost.net_price.private.by_income_level.30001-48000',
#        '2015.cost.net_price.private.by_income_level.48001-75000',
#        '2015.cost.net_price.private.by_income_level.75000-plus',
#        '2015.cost.net_price.private.by_income_level.75001-110000',
#        '2015.cost.net_price.public.by_income_level.0-30000',
#        '2015.cost.net_price.public.by_income_level.110001-plus',
#        '2015.cost.net_price.public.by_income_level.30001-48000',
#        '2015.cost.net_price.public.by_income_level.48001-75000',
#        '2015.cost.net_price.public.by_income_level.75000-plus',
#        '2015.cost.net_price.public.by_income_level.75001-110000',
#        '2015.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings',
#        '2015.repayment.1_yr_repayment.completers', '2015.student.size', 'id',
#        'school.degrees_awarded.predominant',
#        'school.instructional_expenditure_per_fte', 'school.name',
#        'school.tuition_revenue_per_fte'],
#       dtype='object')

# %%
school_df.to_csv(path_or_buf = 'SAT_Scores', index=False)
