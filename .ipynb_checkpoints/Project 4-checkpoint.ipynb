# %%
import requests
import json
import pandas as pd

# %%
api_key = 'ZXCH94jmLisJ8b72hhJC31sCKyZHmEwBxTcp763u'

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?school.degrees_awarded.predominant=1,2,3,4&_fields=id,school.name,2013.student.size,school.degrees_awarded.predominant,2013.admissions.admission_rate.overall,2013.admissions.sat_scores.average.overall'

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=school.name,id,2013.aid.median_debt.completers.overall,2013.cost.private.by_income_level.0-30000,2013.cost.private.by_income_level.30001-75000,2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings'

# %%
# https://api.data.gov/ed/collegescorecard/v1/schools?fields=school.name,id,2013.aid.median_debt.completers.overall,2013.repayment.1_yr_repayment.completers,2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings'

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=school.name,id,2013.aid.median_debt.completers.overall,2013.cost.net_price.other_acad_calendar.by_income_level.0-30000,2013.cost.net_price.other_acad_calendar.by_income_level.30001-75000,2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings'

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=school.name,id,2013.cost.avg_net_price.overall,2013.cost.net_price.public.by_income_level.0-30000,2013.cost.net_price.public.by_income_level.110001-plus,2013.cost.net_price.public.by_income_level.30001-48000,2013.cost.net_price.public.by_income_level.48001-75000,2013.cost.net_price.public.by_income_level.75001-110000,2013.cost.net_price.public.by_income_level.75000-plus,2013.cost.net_price.private.by_income_level.0-30000,2013.cost.net_price.private.by_income_level.110001-plus,2013.cost.net_price.private.by_income_level.30001-48000,2013.cost.net_price.private.by_income_level.48001-75000,2013.cost.net_price.private.by_income_level.75001-110000,2013.cost.net_price.private.by_income_level.75000-plus'

# %% [markdown]
# This is the link I'm using for SAT scores

# %%
link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?&_fields=school.name,id,2013.admissions.sat_scores.25th_percentile.critical_reading,2013.admissions.sat_scores.25th_percentile.math,2013.admissions.sat_scores.25th_percentile.writing,2013.admissions.sat_scores.75th_percentile.critical_reading,2013.admissions.sat_scores.75th_percentile.math,2013.admissions.sat_scores.75th_percentile.writing'

# %%
# link = 'https://api.data.gov/ed/collegescorecard/v1/schools.json?id=164924&_fields=2015.admissions.admission_rate.overall,school.name,id'

# %%
params = {
        'api_key':api_key,
        '_page':1,
        '_per_page':100}

# %%
res = requests.get(link, params)
schools = json.loads(res.content)

# %%
schools
# Out:
# {'metadata': {'page': 1, 'per_page': 100, 'total': 7593},
#  'results': [{'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 11835606,
#    'school.name': 'Marinello School of Beauty-San Diego'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 11835608,
#    'school.name': 'Marinello School of Beauty-West Covina'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 11835609,
#    'school.name': 'Marinello School of Beauty-West Los Angeles'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 18017901,
#    'school.name': 'City College Montana State University Billings'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 18945901,
#    'school.name': 'Briarcliffe College-Patchogue'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 22496101,
#    'school.name': 'Galveston College - Charlie Thomas Family Applied Technology Center'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 37207301,
#    'school.name': 'Fremont College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 37369601,
#    'school.name': 'Rob Roy Academy - Woonsocket'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 37593901,
#    'school.name': 'YTI Career Institute - Altoona'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 43601201,
#    'school.name': 'Franklin Career Institute'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 45538101,
#    'school.name': 'Utah County Campus'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 188289,
#    'school.name': 'Vogue College of Cosmetology-Santa Fe'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 212452,
#    'school.name': 'Faith Theological Seminary'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 449922,
#    'school.name': 'Appalachian College of Pharmacy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480161,
#    'school.name': 'Ideal Beauty Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480550,
#    'school.name': 'Ross Medical Education Center-Bowling Green'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480693,
#    'school.name': 'Columbia Institute'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480781,
#    'school.name': 'California Miramar University'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480815,
#    'school.name': 'Virginia College-Greensboro'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480912,
#    'school.name': 'Gemini School of Visual Arts & Communication'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480976,
#    'school.name': 'The Salon Professional Academy-Huntsville'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481003,
#    'school.name': 'M T Training Center'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481021,
#    'school.name': 'Berks Career & Technology Center'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481049,
#    'school.name': 'Carthage R9 School District-Carthage Technical Center'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481058,
#    'school.name': 'Grace Mission University'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481085,
#    'school.name': 'PCCTI IT and Healthcare'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481100,
#    'school.name': 'Top Nails & Hair Beauty School'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481128,
#    'school.name': 'Santa Ana Beauty College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481182,
#    'school.name': 'Ukiah Adult School'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481261,
#    'school.name': 'Beautiful You School of Nail Technology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481289,
#    'school.name': 'Xavier College School of Nursing'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481298,
#    'school.name': 'Lawrence & Company College of Cosmetology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481304,
#    'school.name': 'Cactus Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481322,
#    'school.name': 'Southern Texas Careers Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481340,
#    'school.name': 'The Salon Professional Academy-Nashville'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481359,
#    'school.name': 'Cosmotech School of Cosmetology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481368,
#    'school.name': 'Prestige Health & Beauty Sciences Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481401,
#    'school.name': 'Grace School of Theology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481410,
#    'school.name': 'Yeshiva Gedolah Kesser Torah'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481456,
#    'school.name': 'Bonnie Joseph Academy of Cosmetology and Barbering'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481465,
#    'school.name': 'Healthcare Training Institute'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481526,
#    'school.name': 'The Chrysm Insitute of Esthetics'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481599,
#    'school.name': 'Dorsey Business Schools-Lansing'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481669,
#    'school.name': 'Tulsa Welding School-Tulsa'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481739,
#    'school.name': 'Empire Beauty School-Vernon Hills'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481854,
#    'school.name': 'American Career College-Long Beach'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 481988,
#    'school.name': "Vatterott College-ex'treme Institute by Nelly-St Louis"},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482060,
#    'school.name': 'Milan Institute-Merced'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482158,
#    'school.name': 'Middle Georgia State University'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482176,
#    'school.name': 'Paul Mitchell the School-Denver'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482185,
#    'school.name': 'Academy of Interactive Entertainment'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482228,
#    'school.name': 'Virginia Baptist College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482264,
#    'school.name': 'Tulsa Technology Center-Owasso Campus'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482273,
#    'school.name': 'Tulsa Technology Center-Sand Springs Campus'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482307,
#    'school.name': 'National American University-Austin South'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482316,
#    'school.name': 'National American University-Lewisville'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482343,
#    'school.name': 'National American University-Rochester'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482361,
#    'school.name': 'National American University-Wichita West'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482389,
#    'school.name': 'National American University-Tigard'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482398,
#    'school.name': 'The Art Institute of St Louis'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482422,
#    'school.name': 'DeVry University-Arizona'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482431,
#    'school.name': 'DeVry University-California'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482477,
#    'school.name': 'DeVry University-Illinois'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482510,
#    'school.name': 'DeVry University-Michigan'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482547,
#    'school.name': 'DeVry University-Nevada'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482574,
#    'school.name': 'DeVry University-Ohio'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482635,
#    'school.name': 'DeVry University-Texas'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482653,
#    'school.name': 'DeVry University-Virginia'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': 450.0,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': 560.0,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482680,
#    'school.name': 'University of North Georgia'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482699,
#    'school.name': 'South Georgia State College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 482990,
#    'school.name': 'Arizona College-Mesa'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 483045,
#    'school.name': 'Central Georgia Technical College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 483054,
#    'school.name': 'Barber School of Pittsburgh'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 11473401,
#    'school.name': 'Franciscan School of Theology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 16947920,
#    'school.name': 'Davenport University-Grand Rapids Downtown'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 450711,
#    'school.name': 'Trend Barber College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 468848,
#    'school.name': 'United Education Institute-UEI College San Marcos'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 468909,
#    'school.name': 'United Education Institute-Anaheim'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 470038,
#    'school.name': 'UEI College-Riverside'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 480471,
#    'school.name': 'United Education Institute-UEI College Stockton'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 483018,
#    'school.name': 'Antioch College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485403,
#    'school.name': 'High Tech High Graduate School of Education'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485476,
#    'school.name': 'Studio Beauty School'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485519,
#    'school.name': 'International Sports Sciences Association'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485528,
#    'school.name': 'International Hair and Barber Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485546,
#    'school.name': 'California Intercontinental University'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485582,
#    'school.name': 'MKG Beauty & Business'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485591,
#    'school.name': 'New Beginnings Beauty Academy'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485731,
#    'school.name': 'The Beauty School'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485768,
#    'school.name': 'Atlantis University'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485801,
#    'school.name': 'Westchester School for Dental Assistant'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 485810,
#    'school.name': 'K & G 5 Star Barber College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486099,
#    'school.name': 'GDS Institute'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486202,
#    'school.name': 'Mingo Extended Learning Center'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486293,
#    'school.name': 'Bay Area College of Nursing'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486309,
#    'school.name': 'Bella Academy of Cosmetology'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486345,
#    'school.name': 'HVAC Technical Institute'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486354,
#    'school.name': 'Unilatina International College'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486415,
#    'school.name': 'AMG School of Licensed Practical Nursing'},
#   {'2011.admissions.sat_scores.25th_percentile.critical_reading': None,
#    '2011.admissions.sat_scores.75th_percentile.critical_reading': None,
#    '2013.admissions.sat_scores.25th_percentile.math': None,
#    '2013.admissions.sat_scores.25th_percentile.writing': None,
#    '2013.admissions.sat_scores.75th_percentile.math': None,
#    '2013.admissions.sat_scores.75th_percentile.writing': None,
#    'id': 486442,
#    'school.name': 'Sandra Academy of Salon Services Inc'}]}

# %%
school_df = pd.DataFrame(schools['results'])

# %%
school_df.head(1)
# Out:
#   2013.completion.rate_suppressed.four_year  \
# 0                                      None
#
#   2013.completion.rate_suppressed.four_year_200percent  \
# 0                                               None
#
#   2013.completion.rate_suppressed.lt_four_year  \
# 0                                         None
#
#   2013.completion.rate_suppressed.lt_four_year_150percent  \
# 0                                               None
#
#   2013.completion.rate_suppressed.overall      id  \
# 0                                    None  443030
#
#                                          school.name
# 0  NorthShore University HealthSystem School of N...

# %%
for x in range (2, 753):
    params = {
        'api_key':api_key,
        '_page':x,
        '_per_page':100}
    res = requests.get(link, params)
    sc = json.loads(res.content)
    sc2 = pd.DataFrame(sc['results'])
    school_df = school_df.append(sc2)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-697-9ef84de41935> in <module>()
#       5         '_per_page':100}
#       6     res = requests.get(link, params)
# ----> 7     sc = json.loads(res.content)
#       8     sc2 = pd.DataFrame(sc['results'])
#       9     school_df = school_df.append(sc2)
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Users/allychrystal/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
school_df.shape
# Out:
# (7493, 8)

# %%
school_df.isnull().sum()
# Out:
# 2011.admissions.sat_scores.25th_percentile.critical_reading    6247
# 2011.admissions.sat_scores.75th_percentile.critical_reading    6247
# 2013.admissions.sat_scores.25th_percentile.math                6188
# 2013.admissions.sat_scores.25th_percentile.writing             6706
# 2013.admissions.sat_scores.75th_percentile.math                6188
# 2013.admissions.sat_scores.75th_percentile.writing             6706
# id                                                                0
# school.name                                                       0
# dtype: int64

# %%
school_df.to_csv(path_or_buf = 'SAT_Scores', index=False)
