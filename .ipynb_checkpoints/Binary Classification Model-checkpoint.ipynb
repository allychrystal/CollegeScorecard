# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import Ridge, Lasso, ElasticNet, LinearRegression, LogisticRegression, RidgeCV, LassoCV, ElasticNetCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn import linear_model as lm
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split, KFold
from sklearn.feature_selection import RFE, SelectKBest, f_classif, f_regression
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Upload Data

# %%
school_scores = pd.read_csv('School_Scores')

# %%
school_no_scores = pd.read_csv('School_No_Scores')

# %% [markdown]
# #### Correlation Heatmap

# %%
sns.heatmap(school_scores.corr())

# %%
fig, ax = plt.subplots(figsize=[4,4])
ax.scatter(school_scores['Total_Cost'], school_scores['Earnings_10yrs'])
plt.xlabel('Total Cost')
plt.ylabel('Mean Earnings')

# %%
fig, ax = plt.subplots(figsize=[4,4])
ax.scatter(school_scores['SAT_25th_Cum'], school_scores['Earnings_10yrs'])
plt.xlabel('SAT_Low_Range')
plt.ylabel('Mean Earnings')

# %%
fig, ax = plt.subplots(figsize=[4,4])
ax.scatter(school_scores['SAT_25th_Cum'], school_scores['Target'])
plt.xlabel('SAT Low Range')
plt.ylabel('Mean Earnings')

# %% [markdown]
# ### Classification Modeling

# %% [raw]
# Predict future salary range after 10 years after program completion
# - 0: $20,000 - $40,000
# - 1: $40,000 - $60,000
# - 2: $60,000 - $80,000
# - 3: $80,000 - Over

# %%
school_scores['Target'] = school_scores['Earnings_10yrs'].map(lambda x: 0 if x < 40000 else 1 if x < 60000 else 2 if x < 80000 else 3)

# %%
school_no_scores['Target'] = school_no_scores['Earnings_10yrs'].map(lambda x: 0 if x < 40000 else 1 if x < 60000 else 2 if x < 80000 else 3)

# %%
school_scores['Target'].value_counts()
# Out:
# 1    660
# 0    244
# 2     99
# 3     49
# Name: Target, dtype: int64

# %%
school_no_scores['Target'].value_counts()
# Out:
# 1    965
# 0    625
# 2    130
# 3     53
# Name: Target, dtype: int64

# %%
correlation = (school_scores.corr()['Target'].apply(lambda x: abs(x)).sort_values(ascending=False))

# %%
corr_df = pd.DataFrame()
corr_df['Correlations'] = correlation
corr_df['Feature'] =correlation.index
corr_df.drop(['Earnings_10yrs', 'ID', 'Target'], inplace= True)

# %%
plt.figure(figsize=(25, 5))
sns.barplot('Feature', 'Correlations', data= corr_df, palette='copper')
plt.title('Correlation Importance', size= 20)
plt.xlabel('Feature', size= 20)
plt.ylabel('Correlation (Absolute Value)', size= 20)
plt.tick_params(labelsize=13)
plt.show()

# %%
fig, ax = plt.subplots(figsize=[4,4])
plt.scatter(school_scores['SAT_25th_Cum'], school_scores['Earnings_10yrs'], c=school_scores['Target'], cmap='copper')
plt.xlabel('SAT Low Range')
plt.ylabel('Mean Earnings')

# %%
plotter = school_scores[[ 'Admission_Rate', 'Fed_Loan_Rate', 'Median_Debt',
       'Pell_Grant_Rate', 'Student_Size', 'Degrees_Awarded',
        'High_Net_Price', 'Low_Net_Price',
       'SAT_25th_Cum', 'SAT_75th_Cum', 'Total_Cost',
       'Target']]

# %%
sns.pairplot(plotter, hue= 'Target', palette='copper')

# %% [markdown]
# ### Classification Modeling

# %% [markdown]
# #### Baseline Calculation

# %%
baseline_acc = round((school_scores['Target'].value_counts().max()) / (y.shape[0]), 2)
baseline_acc
# Out:
# 0.63

# %% [markdown]
# #### Data Train/ Test Split

# %%
X = school_scores[['Admission_Rate', 'Fed_Loan_Rate', 'Median_Debt',
                   'Pell_Grant_Rate', 'Student_Size', 'Degrees_Awarded',
                   'High_Net_Price', 'Low_Net_Price', 'Avg_Net_Price',
                   'SAT_25th_Cum', 'SAT_75th_Cum', 'ACT_25th', 'ACT_75th', 'Total_Cost']].copy()
y = school_scores['Target'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33)

# %%
ss= StandardScaler()
Xs_train= ss.fit_transform(X_train)
Xs_test = ss.transform(X_test)

# %% [markdown]
# #### KNN Model

# %%
knn = KNeighborsClassifier(n_neighbors= 13)
knn.fit(Xs_train, y_train)

y_pred_knn = knn.predict(Xs_test)
print(metrics.accuracy_score(y_test, y_pred_knn))
# Out:
# 0.712643678161

# %%
# KNN cross-val score
scores_knn = cross_val_score(knn, Xs_train, y_train, cv=5)
print(scores_knn)
print(np.mean(scores_knn))
# Out:
# [ 0.72027972  0.6971831   0.70921986  0.69784173  0.71942446]
# 0.708789772816

# %%
# KNN Confusion matrix
from sklearn.metrics import confusion_matrix
predicted = knn.predict(Xs_test)
confusion_matrix(y_test, predicted)
# Out:
# array([[ 31,  40,   1,   0],
#        [ 24, 196,   5,   2],
#        [  1,  19,  10,   3],
#        [  0,   2,   3,  11]])

# %% [markdown]
# ### Ensemble Model

# %%
# Ensemble Model
clf = DecisionTreeClassifier(max_depth=3)
bag_clf = BaggingClassifier(clf)

bag_clf.fit(Xs_train, y_train)
y_pred_bag = bag_clf.predict(Xs_test)
print(metrics.accuracy_score(y_test, y_pred_bag))
# Out:
# 0.727011494253

# %%
# Ensemble cross-val score
scores_bag = cross_val_score(bag_clf, Xs_train, y_train, cv=5)
print(scores_bag)
print(np.mean(scores_bag))
# Out:
# [ 0.72727273  0.67605634  0.66666667  0.68345324  0.74820144]
# 0.700330081645

# %%
# Ensemble Confusion Matrix
predicted_bag = bag_clf.predict(Xs_test)
confusion_matrix(y_test, predicted_bag)
# Out:
# array([[ 28,  44,   0,   0],
#        [ 13, 204,   8,   2],
#        [  0,  17,  10,   6],
#        [  0,   2,   3,  11]])

# %% [markdown]
# ### Comparing Models

# %%
# Comparing All Models
print("KNN Score:\t", cross_val_score(knn, Xs_test, y_test, cv=5, n_jobs=1).mean())
print("Bagging Score:\t", cross_val_score(bag_clf, Xs_test, y_test, cv=5, n_jobs=1).mean())
print("Baseline Score:\t", baseline_acc)
# Out:
# KNN Score:	 0.710037262507
# Bagging Score:	 0.768033292108
# Baseline Score:	 0.63

# %% [markdown]
# ## Adding More Features

# %% [markdown]
# Not satisfied with the accuracy score of previous model.
# I am importing new features on the percentage of races that make up the student demographics

# %%
race = pd.read_csv('Race_Final')

# %%
race = race.drop('Unnamed: 0', axis=1)

# %%
race = race.set_index('id')
# school_scores = school_scores.set_index('ID')

# %%
new_data = pd.concat([school_scores, race], axis=1, join='inner')

# %%
school_scores.shape
# Out:
# (1052, 17)

# %%
new_data.shape
# Out:
# (1039, 27)

# %%
new_data.isnull().sum()
# Out:
# Earnings_10yrs        0
# Admission_Rate        0
# Fed_Loan_Rate         0
# Median_Debt           0
# Pell_Grant_Rate       0
# Student_Size          0
# Degrees_Awarded       0
# School_Name           0
# High_Net_Price        0
# Low_Net_Price         0
# Avg_Net_Price         0
# SAT_25th_Cum          0
# SAT_75th_Cum          0
# ACT_25th              0
# ACT_75th              0
# Total_Cost            0
# Target                0
# aian                  0
# asian                 0
# black                 0
# hispanic              0
# nhpi                  0
# non_resident_alien    0
# two_or_more           0
# unknown               0
# white                 0
# school.name           0
# dtype: int64

# %%
X_new = new_data[[ 'Admission_Rate', 'Fed_Loan_Rate', 'Median_Debt',
       'Pell_Grant_Rate', 'Student_Size', 'Degrees_Awarded',
       'High_Net_Price', 'Low_Net_Price', 'Avg_Net_Price', 'SAT_25th_Cum',
       'SAT_75th_Cum', 'ACT_25th', 'ACT_75th', 'Total_Cost', 'aian',
       'asian', 'black', 'hispanic', 'nhpi', 'non_resident_alien',
       'two_or_more', 'unknown', 'white']]
y_new = new_data['Target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X_new, y_new, test_size = 0.33)

# %%
ss= StandardScaler()
Xs_train= ss.fit_transform(X_train)
Xs_test = ss.transform(X_test)

# %% [markdown]
# ##### Ensemble Model & Cross-Val Score

# %%
clf = DecisionTreeClassifier(max_depth=5)
bag_clf = BaggingClassifier(clf)

bag_clf.fit(Xs_train, y_train)
y_pred_bag = bag_clf.predict(Xs_test)
print(metrics.accuracy_score(y_test, y_pred_bag))
# Out:
# 0.702623906706

# %%
scores_bag = cross_val_score(bag_clf, Xs_train, y_train, cv=5)
print(scores_bag)
print(np.mean(scores_bag))
# Out:
# [ 0.75886525  0.73571429  0.74100719  0.76978417  0.75912409]
# 0.752898997688

# %% [markdown]
# ##### KNN Model & Cross-Val Score

# %%
knn = KNeighborsClassifier(n_neighbors= 14)
knn.fit(Xs_train, y_train)

y_pred_knn = knn.predict(Xs_test)
print(metrics.accuracy_score(y_test, y_pred_knn))
# Out:
# 0.68221574344

# %%
scores_knn = cross_val_score(knn, Xs_train, y_train, cv=5)
print(scores_knn)
print(np.mean(scores_knn))
# Out:
# [ 0.70921986  0.7         0.71223022  0.74820144  0.71532847]
# 0.716995995997

# %% [markdown]
# ##### KNN Grid Search

# %%
knn_dict = {
    'n_neighbors': [10, 12, 14, 16],
    'p': [1, 2],
    'weights': ['uniform', 'distance']}

# %%
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, knn_dict, verbose=2, n_jobs=-1)
grid_search.fit(Xs_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] n_neighbors=10, p=1, weights=uniform ............................
# [CV] n_neighbors=10, p=1, weights=uniform ............................
# [CV] n_neighbors=10, p=1, weights=uniform ............................
# [CV] n_neighbors=10, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=10, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=10, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=10, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=10, p=1, weights=distance ...........................
# [CV] ............ n_neighbors=10, p=1, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=10, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=10, p=2, weights=uniform ............................
# [CV] n_neighbors=10, p=2, weights=uniform ............................
# [CV] ............ n_neighbors=10, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=10, p=2, weights=uniform ............................
# [CV] ............. n_neighbors=10, p=2, weights=uniform, total=   0.0s
# [CV] ............ n_neighbors=10, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=12, p=1, weights=uniform ............................
# [CV] n_neighbors=12, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=10, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=12, p=2, weights=uniform ............................
# [CV] ............. n_neighbors=10, p=2, weights=uniform, total=   0.0s
# [CV] ............. n_neighbors=12, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=10, p=2, weights=distance ...........................
# [CV] ............. n_neighbors=12, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=12, p=2, weights=distance ...........................
# [CV] n_neighbors=12, p=1, weights=uniform ............................
# [CV] ............ n_neighbors=12, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=12, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=12, p=1, weights=uniform, total=   0.0s
# [CV] ............ n_neighbors=10, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=10, p=2, weights=distance ...........................
# [CV] n_neighbors=12, p=1, weights=uniform ............................
# [CV] ............ n_neighbors=12, p=1, weights=distance, total=   0.0s
# [CV] ............ n_neighbors=12, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=12, p=2, weights=uniform ............................
# [CV] n_neighbors=12, p=2, weights=distance ...........................
# [CV] ............ n_neighbors=10, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=10, p=2, weights=distance ...........................
# [CV] ............ n_neighbors=12, p=2, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=12, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=12, p=2, weights=distance ...........................
# [CV] ............. n_neighbors=12, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=12, p=2, weights=uniform ............................
# [CV] n_neighbors=12, p=1, weights=distance ...........................
# [CV] ............ n_neighbors=10, p=2, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=12, p=2, weights=uniform, total=   0.0s
# [CV] ............ n_neighbors=12, p=2, weights=distance, total=   0.0s
# [CV] ............ n_neighbors=12, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=14, p=1, weights=distance ...........................
# [CV] n_neighbors=14, p=1, weights=uniform ............................
# [CV] n_neighbors=14, p=2, weights=uniform ............................
# [CV] n_neighbors=16, p=1, weights=uniform ............................
# [CV] ............. n_neighbors=14, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=14, p=1, weights=uniform ............................
# [CV] ............ n_neighbors=14, p=1, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=16, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=14, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=14, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=1, weights=uniform ............................
# [CV] ............. n_neighbors=14, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=14, p=2, weights=distance ...........................
# [CV] ............ n_neighbors=14, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=14, p=2, weights=uniform ............................
# [CV] n_neighbors=14, p=1, weights=uniform ............................
# [CV] ............. n_neighbors=16, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=1, weights=uniform ............................
# [CV] ............ n_neighbors=14, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=14, p=2, weights=distance ...........................
# [CV] ............. n_neighbors=14, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=14, p=1, weights=distance ...........................
# [CV] ............. n_neighbors=14, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=14, p=2, weights=uniform ............................
# [CV] ............. n_neighbors=16, p=1, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=1, weights=distance ...........................
# [CV] ............ n_neighbors=14, p=2, weights=distance, total=   0.0s
# [CV] ............ n_neighbors=14, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=14, p=2, weights=distance ...........................
# [CV] n_neighbors=16, p=1, weights=distance ...........................
# [CV] ............ n_neighbors=16, p=1, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=14, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=uniform ............................
# [CV] ............ n_neighbors=16, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=16, p=1, weights=distance ...........................
# [CV] ............ n_neighbors=14, p=2, weights=distance, total=   0.0s
# [CV] ............. n_neighbors=16, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=distance ...........................
# [CV] ............ n_neighbors=16, p=1, weights=distance, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=uniform ............................
# [CV] ............ n_neighbors=16, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=distance ...........................
# [CV] ............. n_neighbors=16, p=2, weights=uniform, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=uniform ............................
# [CV] ............ n_neighbors=16, p=2, weights=distance, total=   0.0s
# [CV] n_neighbors=16, p=2, weights=distance ...........................
# [CV] ............. n_neighbors=16, p=2, weights=uniform, total=   0.0s
# [CV] ............ n_neighbors=16, p=2, weights=distance, total=   0.0s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.7s finished
# GridSearchCV(cv=None, error_score='raise',
#        estimator=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform'),
#        fit_params=None, iid=True, n_jobs=-1,
#        param_grid={'n_neighbors': [10, 12, 14, 16], 'p': [1, 2], 'weights': ['uniform', 'distance']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=2)

# %%
grid_search.best_score_
# Out:
# 0.73275862068965514

# %%
grid_search.best_params_
# Out:
# {'n_neighbors': 10, 'p': 1, 'weights': 'uniform'}

# %%
y_test_pred = grid_search.best_estimator_.predict(Xs_test)

# %%
print(metrics.accuracy_score(y_test, y_test_pred))
# Out:
# 0.679300291545

# %% [markdown]
# ##### Model can predict the mean earnings of students 10 years after graduation with 76.68% accuracy

# %% [markdown]
# Next Steps:
# - You can use this data for many more applications like deciding what tuition should be, identifying schools that are low cost with high earnings potential for low-income students, etc  See my search engine notebook for real-world application.
# - Add more features to dataset.  I'd like to add information on what category of programs are offered.  I believe schools with a high percentage of STEM (science, technology, engineering, math) classes will positively correlate with earnings potential. In addition to profressional specialty programs (aviation, law, psychology) will also positively correlate with earnings potential)
